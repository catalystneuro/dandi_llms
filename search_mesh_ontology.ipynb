# %% [markdown]
# # MeSH terms search

# %%
import requests

# %%
def perform_mesh_query(label, match: str="contains", year: str="2023", limit: int=10):
    base_url = "https://id.nlm.nih.gov/mesh/lookup/descriptor"
    params = {
        "label": label,
        "match": match,
        "year": year,
        "limit": limit
    }
    headers = {
        "accept": "application/json"
    }

    try:
        response = requests.get(base_url, params=params, headers=headers)
        response.raise_for_status()
        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        print(f"Error occurred: {e}")
        return None

# %%
label = "gaba"
match = "contains"
year = "2023"
limit = 20

result = perform_mesh_query(label, match, year, limit)
if result:
    for r in result:
        print(r)
# Out:
# {'resource': 'http://id.nlm.nih.gov/mesh/2023/D018682', 'label': 'GABA Agents'}
# {'resource': 'http://id.nlm.nih.gov/mesh/2023/D018755', 'label': 'GABA Agonists'}
# {'resource': 'http://id.nlm.nih.gov/mesh/2023/D018756', 'label': 'GABA Antagonists'}
# {'resource': 'http://id.nlm.nih.gov/mesh/2023/D018757', 'label': 'GABA Modulators'}
# {'resource': 'http://id.nlm.nih.gov/mesh/2023/D050485', 'label': 'GABA Plasma Membrane Transport Proteins'}
# {'resource': 'http://id.nlm.nih.gov/mesh/2023/D058805', 'label': 'GABA Uptake Inhibitors'}
# {'resource': 'http://id.nlm.nih.gov/mesh/2023/D058785', 'label': 'GABA-A Receptor Agonists'}
# {'resource': 'http://id.nlm.nih.gov/mesh/2023/D058787', 'label': 'GABA-A Receptor Antagonists'}
# {'resource': 'http://id.nlm.nih.gov/mesh/2023/D058786', 'label': 'GABA-B Receptor Agonists'}
# {'resource': 'http://id.nlm.nih.gov/mesh/2023/D058788', 'label': 'GABA-B Receptor Antagonists'}
# {'resource': 'http://id.nlm.nih.gov/mesh/2023/D059330', 'label': 'GABAergic Neurons'}
# {'resource': 'http://id.nlm.nih.gov/mesh/2023/D000077206', 'label': 'Gabapentin'}
# {'resource': 'http://id.nlm.nih.gov/mesh/2023/D018079', 'label': 'Receptors, GABA'}
# {'resource': 'http://id.nlm.nih.gov/mesh/2023/D011963', 'label': 'Receptors, GABA-A'}
# {'resource': 'http://id.nlm.nih.gov/mesh/2023/D018080', 'label': 'Receptors, GABA-B'}

# %% [markdown]
# # Load text from pdf

# %%
from langchain.document_loaders import PyPDFLoader

# %%
file_path = "/media/luiz/storage2/taufferconsulting/client_catalystneuro/project_llms/papers/science.1125572.pdf"
loader = PyPDFLoader(file_path)
pages = loader.load_and_split()
del pages[0]
full_text = " ".join([p.page_content for p in pages])
split_text = "Conjunctive Representation of"
full_text = split_text + full_text.split(split_text)[1]
full_text

# %%
file_path = "/media/luiz/storage2/taufferconsulting/client_catalystneuro/project_llms/papers/sargolini_som.pdf"
loader = PyPDFLoader(file_path)
pages = loader.load_and_split()
del pages[0]
supporting_material = " ".join([p.page_content for p in pages])
supporting_material

# %% [markdown]
# # Extract terms from text

# %%
import openai
from langchain.chat_models import ChatOpenAI
from langchain.chains import create_extraction_chain

# %%
def keywords_extraction(user_input: str, model: str = "gpt-3.5-turbo"):
    llm = ChatOpenAI(
        model=model,
        temperature=0
    )
    schema = {
        "properties": {
            "neuroscience_terms": {
                "type": "string",
                "description": """extensive list of neuroscience and biological scientific experiment terms present in the text, Medical Subject Headings, neuroscience ontology. 
These can include but are not limited to: 
species - Biological species taxonomies, 
approaches - Experimental approaches in neuroscience, such as electrophysiology, calcium imaging, etc.
measurement techniques - Measurement techniques, such as patch clamp, two-photon imaging, spike sorting, etc.
variables measured - Variables measured, such as membrane potential, spike rate, position, etc.
anatomy - Anatomical regions, such as hippocampus, cortex, etc.
disease - Disease models, such as Alzheimer's, Parkinson's, etc.
cell types - Cell types, such as pyramidal, interneuron, etc.
drugs - Drugs, such as ketamine, nitrous oxide, etc.""",
            },
            # "species": {
            #     "type": "string",
            #     "description": "Biological species taxonomies",
            # },
            # "approaches": {
            #     "type": "string",
            #     "description": "Experimental approaches in neuroscience, such as electrophysiology, calcium imaging, etc.",
            # },
            # "measurement_techniques": {
            #     "type": "string",
            #     "description": "Measurement techniques, such as patch clamp, two-photon imaging, spike sorting, etc.",
            # },
            # "variables_measured": {
            #     "type": "string",
            #     "description": "Variables measured, such as membrane potential, spike rate, position, etc.",
            # },
            # "anatomy": {
            #     "type": "string",
            #     "description": "Anatomical regions, such as hippocampus, cortex, etc.",
            # },
            # "disease": {
            #     "type": "string",
            #     "description": "Disease models, such as Alzheimer's, Parkinson's, etc.",
            # },
            # "cell_types": {
            #     "type": "string",
            #     "description": "Cell types, such as pyramidal, interneuron, etc.",
            # },
            # "drugs": {
            #     "type": "string",
            #     "description": "Drugs, such as ketamine, nitrous oxide, etc.",
            # }
        },
        "required": [],
    }
    chain = create_extraction_chain(schema, llm)
    return chain.run(user_input)

# %%
r = keywords_extraction(full_text, model="gpt-3.5-turbo-16k")
r
# Out:
# [{'neuroscience_terms': 'Conjunctive Representation, Position, Direction, Velocity, Entorhinal Cortex, Grid cells, Medial entorhinal cortex, Principal cell layer, Head-direction cells, Conjunctive grid /C2head-direction cells'}]

# %%
terms_list = [t for t in r[0]["neuroscience_terms"].split(", ")]
terms_dict = dict()
for t in terms_list:
    terms_dict[t] = perform_mesh_query(label=t)

for k, v in terms_dict.items():
    print(k)
    print(v)
    print()
# Out:
# Conjunctive Representation
# []
#
# Position
# [{'resource': 'http://id.nlm.nih.gov/mesh/2023/D065635', 'label': 'Benign Paroxysmal Positional Vertigo'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D055012', 'label': 'Chromosomal Position Effects'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D045584', 'label': 'Chromosome Positioning'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D056446', 'label': 'Knee-Chest Position'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D056888', 'label': 'Patient Positioning'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D056510', 'label': 'Position-Specific Scoring Matrices'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D016684', 'label': 'Prone Position'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D000077708', 'label': 'Sitting Position'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D000078783', 'label': 'Standing Position'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D016683', 'label': 'Supine Position'}]
#
# Direction
# []
#
# Velocity
# [{'resource': 'http://id.nlm.nih.gov/mesh/2023/D001783', 'label': 'Blood Flow Velocity'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D000080909', 'label': 'Carotid-Femoral Pulse Wave Velocity'}]
#
# Entorhinal Cortex
# [{'resource': 'http://id.nlm.nih.gov/mesh/2023/D018728', 'label': 'Entorhinal Cortex'}]
#
# Grid cells
# [{'resource': 'http://id.nlm.nih.gov/mesh/2023/D000071038', 'label': 'Grid Cells'}]
#
# Medial entorhinal cortex
# []
#
# Principal cell layer
# []
#
# Head-direction cells
# []
#
# Conjunctive grid /C2head-direction cells
# []

# %%
r = keywords_extraction(supporting_material, model="gpt-3.5-turbo-16k")
r
# Out:
# [{'neuroscience_terms': 'Sargolini, rats, Long Evans rats, Plexiglass cages, light/dark schedule, food deprivation schedule, surgery, electrode preparation, microdrive, tetrodes, platinum-iridium wire, electrode impedances, dorsocaudal medial entorhinal cortex, transverse sinus, saggital plane, microdrive, skull, dental cement, stainless steel screws, recording procedures, behavioural testing, training, Axona recording station, AC-coupled unity-gain operational amplifiers, electrodes, signals, spikes, EEG signals, video camera, light-emitting diodes, enclosures, cue card, chocolate crumbs, trials, water, spike sorting, cluster-cutting software, clustering, projections, parameter space, autocorrelation, crosscorrelation functions, place fields, position estimates, firing rate, smoothing algorithm, spatial smoothing, spatial correlation, spatial information rate, autocorrelation of rate maps, grid structure, gridness, grid spacing, grid orientation, spatial periodicity, head-direction cells, directional tuning, directional information rate, velocity tuning, running speed, linear regression, histology, formaldehyde, brain sections, glass slides, cresyl violet staining, electrode positions, three-dimensional surface reconstruction, parahippocampal region'}]

# %%
terms_list = [t for t in r[0]["neuroscience_terms"].split(", ")]
terms_dict = dict()
for t in terms_list:
    terms_dict[t] = perform_mesh_query(label=t)

for k, v in terms_dict.items():
    print(k)
    print(v)
    print()
# Out:
# Sargolini
# []
#
# rats
# [{'resource': 'http://id.nlm.nih.gov/mesh/2023/D019577', 'label': 'Mole Rats'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D051381', 'label': 'Rats'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D011910', 'label': 'Rats, Brattleboro'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D011911', 'label': 'Rats, Gunn'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D054772', 'label': 'Rats, Hairless'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D011912', 'label': 'Rats, Inbred ACI'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D011913', 'label': 'Rats, Inbred BB'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D011914', 'label': 'Rats, Inbred BN'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D011915', 'label': 'Rats, Inbred BUF'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D020303', 'label': 'Rats, Inbred Dahl'}]
#
# Long Evans rats
# []
#
# Plexiglass cages
# []
#
# light/dark schedule
# []
#
# food deprivation schedule
# []
#
# surgery
# [{'resource': 'http://id.nlm.nih.gov/mesh/2023/D050110', 'label': 'Bariatric Surgery'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D003107', 'label': 'Colorectal Surgery'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D061887', 'label': 'Conversion to Open Surgery'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D048988', 'label': 'Corneal Surgery, Laser'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D000080482', 'label': 'Enhanced Recovery After Surgery'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D055111', 'label': 'Failed Back Surgery Syndrome'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D018463', 'label': 'Filtering Surgery'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D013502', 'label': 'General Surgery'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D061145', 'label': 'Microvascular Decompression Surgery'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D015580', 'label': 'Mohs Surgery'}]
#
# electrode preparation
# []
#
# microdrive
# []
#
# tetrodes
# []
#
# platinum-iridium wire
# []
#
# electrode impedances
# []
#
# dorsocaudal medial entorhinal cortex
# []
#
# transverse sinus
# [{'resource': 'http://id.nlm.nih.gov/mesh/2023/D054064', 'label': 'Transverse Sinuses'}]
#
# saggital plane
# []
#
# skull
# [{'resource': 'http://id.nlm.nih.gov/mesh/2023/D012886', 'label': 'Skull'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D019291', 'label': 'Skull Base'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D019292', 'label': 'Skull Base Neoplasms'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D020205', 'label': 'Skull Fracture, Basilar'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D020204', 'label': 'Skull Fracture, Depressed'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D012887', 'label': 'Skull Fractures'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D012888', 'label': 'Skull Neoplasms'}]
#
# dental cement
# [{'resource': 'http://id.nlm.nih.gov/mesh/2023/D003738', 'label': 'Dental Cements'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D003739', 'label': 'Dental Cementum'}]
#
# stainless steel screws
# []
#
# recording procedures
# []
#
# behavioural testing
# []
#
# training
# [{'resource': 'http://id.nlm.nih.gov/mesh/2023/D001326', 'label': 'Autogenic Training'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D000091942', 'label': 'Cognitive Training'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D003200', 'label': 'Computer User Training'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D000076663', 'label': 'Endurance Training'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D000070856', 'label': 'High Fidelity Simulation Training'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D000072696', 'label': 'High-Intensity Interval Training'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D007318', 'label': 'Inservice Training'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D000094562', 'label': 'Olfactory Training'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D010806', 'label': 'Physical Education and Training'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D055070', 'label': 'Resistance Training'}]
#
# Axona recording station
# []
#
# AC-coupled unity-gain operational amplifiers
# []
#
# electrodes
# [{'resource': 'http://id.nlm.nih.gov/mesh/2023/D004566', 'label': 'Electrodes'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D004567', 'label': 'Electrodes, Implanted'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D017736', 'label': 'Ion-Selective Electrodes'}]
#
# signals
# [{'resource': 'http://id.nlm.nih.gov/mesh/2023/D049790', 'label': 'Nuclear Export Signals'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D019913', 'label': 'Nuclear Localization Signals'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D000074404', 'label': 'Peroxisomal Targeting Signals'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D021382', 'label': 'Protein Sorting Signals'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D039104', 'label': "RNA 3' Polyadenylation Signals"}]
#
# spikes
# []
#
# EEG signals
# []
#
# video camera
# []
#
# light-emitting diodes
# []
#
# enclosures
# []
#
# cue card
# []
#
# chocolate crumbs
# []
#
# trials
# [{'resource': 'http://id.nlm.nih.gov/mesh/2023/D000075522', 'label': 'Adaptive Clinical Trials as Topic'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D026661', 'label': 'Clinical Trials Data Monitoring Committees'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D002986', 'label': 'Clinical Trials as Topic'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D017321', 'label': 'Clinical Trials, Phase I as Topic'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D017322', 'label': 'Clinical Trials, Phase II as Topic'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D017326', 'label': 'Clinical Trials, Phase III as Topic'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D017327', 'label': 'Clinical Trials, Phase IV as Topic'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D000078665', 'label': 'Clinical Trials, Veterinary as Topic'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D057176', 'label': 'Compassionate Use Trials'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D018849', 'label': 'Controlled Clinical Trials as Topic'}]
#
# water
# [{'resource': 'http://id.nlm.nih.gov/mesh/2023/D001834', 'label': 'Body Water'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D061545', 'label': 'Carbonated Water'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D000074067', 'label': 'Conservation of Water Resources'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D060766', 'label': 'Drinking Water'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D015633', 'label': 'Extravascular Lung Water'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D005618', 'label': 'Fresh Water'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D008900', 'label': 'Mineral Waters'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D000084443', 'label': 'Morris Water Maze Test'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D000068357', 'label': 'Saline Waters'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D000082463', 'label': 'Sanitary Surveys, Water Supply'}]
#
# spike sorting
# []
#
# cluster-cutting software
# []
#
# clustering
# [{'resource': 'http://id.nlm.nih.gov/mesh/2023/D013029', 'label': 'Space-Time Clustering'}]
#
# projections
# []
#
# parameter space
# []
#
# autocorrelation
# []
#
# crosscorrelation functions
# []
#
# place fields
# []
#
# position estimates
# []
#
# firing rate
# []
#
# smoothing algorithm
# []
#
# spatial smoothing
# []
#
# spatial correlation
# []
#
# spatial information rate
# []
#
# autocorrelation of rate maps
# []
#
# grid structure
# []
#
# gridness
# []
#
# grid spacing
# []
#
# grid orientation
# []
#
# spatial periodicity
# []
#
# head-direction cells
# []
#
# directional tuning
# []
#
# directional information rate
# []
#
# velocity tuning
# []
#
# running speed
# []
#
# linear regression
# []
#
# histology
# [{'resource': 'http://id.nlm.nih.gov/mesh/2023/D006653', 'label': 'Histology'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D006654', 'label': 'Histology, Comparative'}, {'resource': 'http://id.nlm.nih.gov/mesh/2023/D016626', 'label': 'Shadowing Technique, Histology'}]
#
# formaldehyde
# [{'resource': 'http://id.nlm.nih.gov/mesh/2023/D005557', 'label': 'Formaldehyde'}]
#
# brain sections
# []
#
# glass slides
# []
#
# cresyl violet staining
# []
#
# electrode positions
# []
#
# three-dimensional surface reconstruction
# []
#
# parahippocampal region
# []
